# %% [markdown]
# ![Co%CC%81pia%20de%20Aula%2001_%20Algoritmos%20e%20Computac%CC%A7a%CC%83o.png](attachment:Co%CC%81pia%20de%20Aula%2001_%20Algoritmos%20e%20Computac%CC%A7a%CC%83o.png)

# %% [markdown]
# Conteúdo da Aula de hoje:
#
#
# 1. <a href='#section1'>Seção 1 </a>
#
# 2. <a href='#section2'>Seção 2 </a>
# 3. <a href='#section3'>Seção 3 </a>

# %% [markdown]
# <a id='section1'></a>
# # 1. Seção 1
#
# Conteúdo da Seção 1
#
# <a id='section2'></a>
# # 2. Seção 2
#
# Conteúdo da Seção 2
#
# <a id='section3'></a>
# # 3. Seção 3
#
# Conteúdo da seção 3
